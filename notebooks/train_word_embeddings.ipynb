# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics.pairwise import cosine_similarity
from sklearn import preprocessing

from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from gensim.models import Phrases
from gensim.corpora import Dictionary
from gensim.models import Word2Vec

# %%
dataset = catalog.load('raw_dataset')
vocab = catalog.load('dictionary')
# Out:
# 2020-04-03 10:58:06,028 - kedro.io.data_catalog - INFO - Loading data from `raw_dataset` (CSVLocalDataSet)...

# %% [markdown]
# ## Pre-process docs for word embeddings

# %%
def split_by_sentence(docs):
    tmp = []
    for i, doc in enumerate(docs):
        splitted_doc = doc.split('.\n')
        for sd in splitted_doc:
            sentences = sd.split('. ')
            for s in sentences:
                tmp.append(s)
    return tmp

def lowerize(docs):
    # Convert to lowercase.
    for idx in range(len(docs)):
        docs[idx] = str(docs[idx]).lower()
    return docs

def tokenize(docs):
    # Split into words.
    tokenizer = RegexpTokenizer(r'\w+')
    for idx in range(len(docs)):
        docs[idx] = tokenizer.tokenize(docs[idx])
    return docs

def remove_stop_words(docs):
    stop_words = set(stopwords.words('english'))
    for idx in range(len(docs)):
        docs[idx] = [w for w in docs[idx] if not w in stop_words]
    return docs

def remove_numbers(docs):
    # Remove numbers, but not words that contain numbers.
    docs = [[token for token in doc if not token.isnumeric()] for doc in docs]
    return docs

def remove_word_with_length(docs, length=1):
    # Remove words that are only (length=1) character.
    docs = [[token for token in doc if len(token) > length] for doc in docs]
    return docs

def lemmatize(docs):
    # Lemmatize the documents
    lemmatizer = WordNetLemmatizer()
    docs = [[lemmatizer.lemmatize(token) for token in doc] for doc in docs]
    return docs

def add_bigram(docs, min_bigram_count=20):
    # Add bigrams and trigrams to docs (only ones that appear 20 times or more).
    bigram = Phrases(docs, min_count=min_bigram_count)
    for idx in range(len(docs)):
        for token in bigram[docs[idx]]:
            if '_' in token:
                # Token is a bigram, add to document.
                docs[idx].append(token)
    return docs

def remove_vocab(docs, vocab):
    docs = np.array([[w for w in doc if w in vocab] for doc in docs])
    return docs

# %%
min_bigram_count = 20
length = 1
no_below = 100
no_above = 0.70

docs = dataset['text'].values

print('\nSplitting by sentence...')
docs = split_by_sentence(docs)

print('\nLowerizing...')
docs = lowerize(docs)

print('\nTokenizing...')
docs = tokenize(docs)

#print('\nAdding bigrams...')
#docs = add_bigram(docs, min_bigram_count=min_bigram_count)
    
print('\nRemoving stop words...')
docs = remove_stop_words(docs)

print('\nRemoving unique numbers (not words that contain numbers)...')
docs = remove_numbers(docs)

print('\nRemoving words that contain only one character...')
docs = remove_word_with_length(docs, length=length)

print('\nLemmatizing...')
docs = lemmatize(docs)

vocab = Dictionary(docs)
vocab.filter_extremes(no_below=no_below, no_above=no_above)

docs = remove_vocab(docs, list(vocab.token2id))

print('Number of sentences:', len(docs))
print('Number of unique words:', len(vocab))
# Out:
# Splitting by sentence...
#
# Lowerizing...
#
# Tokenizing...
#
# Removing stop words...
#
# Removing unique numbers (not words that contain numbers)...
#
# Removing words that contain only one character...
#
# Lemmatizing...

# %% [markdown]
# ## Train word embeddings (gensim word2vec)

# %%
class MyDocuments(object):
    def __init__(self, docs):
        self.docs = docs
 
    def __iter__(self):
        for line in self.docs:
            yield line

# %%
sentences = MyDocuments(docs)

# %%
size = 300
window = 5
min_count = 1
workers = 8
sg = 1
iter = 50

model = Word2Vec(sentences, size=size, window=window, min_count=min_count, workers=workers, sg=sg, iter=iter)
# Out:
# 2020-03-31 18:38:23,541 - gensim.models.word2vec - INFO - collecting all words and their counts
# 2020-03-31 18:38:23,544 - gensim.models.word2vec - INFO - PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-03-31 18:38:23,598 - gensim.models.word2vec - INFO - PROGRESS: at sentence #10000, processed 152352 words, keeping 7500 word types
# 2020-03-31 18:38:23,622 - gensim.models.word2vec - INFO - PROGRESS: at sentence #20000, processed 301964 words, keeping 8172 word types
# 2020-03-31 18:38:23,646 - gensim.models.word2vec - INFO - PROGRESS: at sentence #30000, processed 459245 words, keeping 8488 word types
# 2020-03-31 18:38:23,668 - gensim.models.word2vec - INFO - PROGRESS: at sentence #40000, processed 595763 words, keeping 8656 word types
# 2020-03-31 18:38:23,693 - gensim.models.word2vec - INFO - PROGRESS: at sentence #50000, processed 744128 words, keeping 8708 word types
# 2020-03-31 18:38:23,720 - gensim.models.word2vec - INFO - PROGRESS: at sentence #60000, processed 901416 words, keeping 8721 word types
# 2020-03-31 18:38:23,744 - gensim.models.word2vec - INFO - PROGRESS: at sentence #70000, processed 1050926 words, keeping 8748 word types
# 2020-03-31 18:38:23,770 - gensim.models.word2vec - INFO - PROGRESS: at sentence #80000, processed 1187816 words, keeping 8762 word types
# 2020-03-31 18:38:23,794 - gensim.models.word2vec - INFO - PROGRESS: at sentence #90000, processed 1332798 words, keeping 8769 word types
# 2020-03-31 18:38:23,818 - gensim.models.word2vec - INFO - PROGRESS: at sentence #100000, processed 1478888 words, keeping 8772 word types
# 2020-03-31 18:38:23,843 - gensim.models.word2vec - INFO - PROGRESS: at sentence #110000, processed 1635574 words, keeping 8775 word types
# 2020-03-31 18:38:23,866 - gensim.models.word2vec - INFO - PROGRESS: at sentence #120000, processed 1785474 words, keeping 8791 word types
# 2020-03-31 18:38:23,889 - gensim.models.word2vec - INFO - PROGRESS: at sentence #130000, processed 1927332 words, keeping 8799 word types
# 2020-03-31 18:38:23,916 - gensim.models.word2vec - INFO - PROGRESS: at sentence #140000, processed 2085865 words, keeping 8805 word types
# 2020-03-31 18:38:23,941 - gensim.models.word2vec - INFO - PROGRESS: at sentence #150000, processed 2246424 words, keeping 8811 word types
# 2020-03-31 18:38:23,964 - gensim.models.word2vec - INFO - PROGRESS: at sentence #160000, processed 2397256 words, keeping 8813 word types
# 2020-03-31 18:38:23,989 - gensim.models.word2vec - INFO - PROGRESS: at sentence #170000, processed 2539275 words, keeping 8817 word types
# 2020-03-31 18:38:24,011 - gensim.models.word2vec - INFO - PROGRESS: at sentence #180000, processed 2676295 words, keeping 8819 word types
# 2020-03-31 18:38:24,036 - gensim.models.word2vec - INFO - PROGRESS: at sentence #190000, processed 2819157 words, keeping 8823 word types
# 2020-03-31 18:38:24,059 - gensim.models.word2vec - INFO - PROGRESS: at sentence #200000, processed 2966934 words, keeping 8825 word types
# 2020-03-31 18:38:24,085 - gensim.models.word2vec - INFO - PROGRESS: at sentence #210000, processed 3128612 words, keeping 8829 word types
# 2020-03-31 18:38:24,109 - gensim.models.word2vec - INFO - PROGRESS: at sentence #220000, processed 3290006 words, keeping 8829 word types
# 2020-03-31 18:38:24,135 - gensim.models.word2vec - INFO - PROGRESS: at sentence #230000, processed 3449854 words, keeping 8831 word types
# 2020-03-31 18:38:24,159 - gensim.models.word2vec - INFO - PROGRESS: at sentence #240000, processed 3605867 words, keeping 8836 word types
# 2020-03-31 18:38:24,182 - gensim.models.word2vec - INFO - PROGRESS: at sentence #250000, processed 3745527 words, keeping 8836 word types
# 2020-03-31 18:38:24,206 - gensim.models.word2vec - INFO - PROGRESS: at sentence #260000, processed 3896874 words, keeping 8838 word types
# 2020-03-31 18:38:24,233 - gensim.models.word2vec - INFO - PROGRESS: at sentence #270000, processed 4054426 words, keeping 8838 word types
# 2020-03-31 18:38:24,259 - gensim.models.word2vec - INFO - PROGRESS: at sentence #280000, processed 4213220 words, keeping 8838 word types
# 2020-03-31 18:38:24,287 - gensim.models.word2vec - INFO - PROGRESS: at sentence #290000, processed 4365895 words, keeping 8838 word types
# 2020-03-31 18:38:24,315 - gensim.models.word2vec - INFO - PROGRESS: at sentence #300000, processed 4509024 words, keeping 8839 word types
# 2020-03-31 18:38:24,341 - gensim.models.word2vec - INFO - PROGRESS: at sentence #310000, processed 4646948 words, keeping 8841 word types
# 2020-03-31 18:38:24,370 - gensim.models.word2vec - INFO - PROGRESS: at sentence #320000, processed 4804740 words, keeping 8842 word types
# 2020-03-31 18:38:24,396 - gensim.models.word2vec - INFO - PROGRESS: at sentence #330000, processed 4967847 words, keeping 8843 word types
# 2020-03-31 18:38:24,422 - gensim.models.word2vec - INFO - PROGRESS: at sentence #340000, processed 5131388 words, keeping 8843 word types
# 2020-03-31 18:38:24,453 - gensim.models.word2vec - INFO - PROGRESS: at sentence #350000, processed 5290496 words, keeping 8844 word types
# 2020-03-31 18:38:24,479 - gensim.models.word2vec - INFO - PROGRESS: at sentence #360000, processed 5442856 words, keeping 8844 word types
# 2020-03-31 18:38:24,507 - gensim.models.word2vec - INFO - PROGRESS: at sentence #370000, processed 5608333 words, keeping 8844 word types
# 2020-03-31 18:38:24,534 - gensim.models.word2vec - INFO - PROGRESS: at sentence #380000, processed 5775538 words, keeping 8844 word types
# 2020-03-31 18:38:24,558 - gensim.models.word2vec - INFO - PROGRESS: at sentence #390000, processed 5922690 words, keeping 8848 word types
# 2020-03-31 18:38:24,586 - gensim.models.word2vec - INFO - PROGRESS: at sentence #400000, processed 6070470 words, keeping 8848 word types
# 2020-03-31 18:38:24,611 - gensim.models.word2vec - INFO - PROGRESS: at sentence #410000, processed 6211493 words, keeping 8850 word types
# 2020-03-31 18:38:24,636 - gensim.models.word2vec - INFO - PROGRESS: at sentence #420000, processed 6362959 words, keeping 8850 word types
# 2020-03-31 18:38:24,662 - gensim.models.word2vec - INFO - PROGRESS: at sentence #430000, processed 6521912 words, keeping 8850 word types
# 2020-03-31 18:38:24,693 - gensim.models.word2vec - INFO - PROGRESS: at sentence #440000, processed 6679710 words, keeping 8851 word types
# 2020-03-31 18:38:24,722 - gensim.models.word2vec - INFO - PROGRESS: at sentence #450000, processed 6835453 words, keeping 8851 word types
# 2020-03-31 18:38:24,746 - gensim.models.word2vec - INFO - PROGRESS: at sentence #460000, processed 6988159 words, keeping 8851 word types
# 2020-03-31 18:38:24,771 - gensim.models.word2vec - INFO - PROGRESS: at sentence #470000, processed 7126410 words, keeping 8851 word types
# 2020-03-31 18:38:24,796 - gensim.models.word2vec - INFO - PROGRESS: at sentence #480000, processed 7267756 words, keeping 8853 word types
# 2020-03-31 18:38:24,819 - gensim.models.word2vec - INFO - PROGRESS: at sentence #490000, processed 7405463 words, keeping 8853 word types
# 2020-03-31 18:38:24,842 - gensim.models.word2vec - INFO - PROGRESS: at sentence #500000, processed 7547829 words, keeping 8853 word types
# 2020-03-31 18:38:24,870 - gensim.models.word2vec - INFO - PROGRESS: at sentence #510000, processed 7702486 words, keeping 8855 word types
# 2020-03-31 18:38:24,896 - gensim.models.word2vec - INFO - PROGRESS: at sentence #520000, processed 7862470 words, keeping 8855 word types
# 2020-03-31 18:38:24,918 - gensim.models.word2vec - INFO - PROGRESS: at sentence #530000, processed 8000449 words, keeping 8859 word types
# 2020-03-31 18:38:24,943 - gensim.models.word2vec - INFO - PROGRESS: at sentence #540000, processed 8137872 words, keeping 8859 word types
# 2020-03-31 18:38:24,967 - gensim.models.word2vec - INFO - PROGRESS: at sentence #550000, processed 8273090 words, keeping 8859 word types
# 2020-03-31 18:38:24,995 - gensim.models.word2vec - INFO - PROGRESS: at sentence #560000, processed 8423076 words, keeping 8859 word types
# 2020-03-31 18:38:25,020 - gensim.models.word2vec - INFO - PROGRESS: at sentence #570000, processed 8581318 words, keeping 8859 word types
# 2020-03-31 18:38:25,044 - gensim.models.word2vec - INFO - PROGRESS: at sentence #580000, processed 8726334 words, keeping 8862 word types
# 2020-03-31 18:38:25,069 - gensim.models.word2vec - INFO - PROGRESS: at sentence #590000, processed 8861712 words, keeping 8867 word types
# 2020-03-31 18:38:25,094 - gensim.models.word2vec - INFO - PROGRESS: at sentence #600000, processed 9012425 words, keeping 8867 word types
# 2020-03-31 18:38:25,117 - gensim.models.word2vec - INFO - PROGRESS: at sentence #610000, processed 9160548 words, keeping 8867 word types
# 2020-03-31 18:38:25,144 - gensim.models.word2vec - INFO - PROGRESS: at sentence #620000, processed 9321236 words, keeping 8867 word types
# 2020-03-31 18:38:25,168 - gensim.models.word2vec - INFO - PROGRESS: at sentence #630000, processed 9479604 words, keeping 8867 word types
# 2020-03-31 18:38:25,193 - gensim.models.word2vec - INFO - PROGRESS: at sentence #640000, processed 9641385 words, keeping 8867 word types
# 2020-03-31 18:38:25,218 - gensim.models.word2vec - INFO - PROGRESS: at sentence #650000, processed 9793223 words, keeping 8867 word types
# 2020-03-31 18:38:25,241 - gensim.models.word2vec - INFO - PROGRESS: at sentence #660000, processed 9940169 words, keeping 8867 word types
# 2020-03-31 18:38:25,266 - gensim.models.word2vec - INFO - PROGRESS: at sentence #670000, processed 10088988 words, keeping 8867 word types
# 2020-03-31 18:38:25,291 - gensim.models.word2vec - INFO - PROGRESS: at sentence #680000, processed 10236861 words, keeping 8867 word types
# 2020-03-31 18:38:25,313 - gensim.models.word2vec - INFO - PROGRESS: at sentence #690000, processed 10385579 words, keeping 8867 word types
# 2020-03-31 18:38:25,339 - gensim.models.word2vec - INFO - PROGRESS: at sentence #700000, processed 10533015 words, keeping 8867 word types
# 2020-03-31 18:38:25,364 - gensim.models.word2vec - INFO - PROGRESS: at sentence #710000, processed 10691261 words, keeping 8867 word types
# 2020-03-31 18:38:25,390 - gensim.models.word2vec - INFO - PROGRESS: at sentence #720000, processed 10847469 words, keeping 8867 word types
# 2020-03-31 18:38:25,412 - gensim.models.word2vec - INFO - PROGRESS: at sentence #730000, processed 10991110 words, keeping 8867 word types
# 2020-03-31 18:38:25,437 - gensim.models.word2vec - INFO - PROGRESS: at sentence #740000, processed 11147848 words, keeping 8867 word types
# 2020-03-31 18:38:25,463 - gensim.models.word2vec - INFO - PROGRESS: at sentence #750000, processed 11305124 words, keeping 8867 word types
# 2020-03-31 18:38:25,487 - gensim.models.word2vec - INFO - PROGRESS: at sentence #760000, processed 11452512 words, keeping 8868 word types
# 2020-03-31 18:38:25,509 - gensim.models.word2vec - INFO - PROGRESS: at sentence #770000, processed 11587694 words, keeping 8868 word types
# 2020-03-31 18:38:25,532 - gensim.models.word2vec - INFO - PROGRESS: at sentence #780000, processed 11723139 words, keeping 8868 word types
# 2020-03-31 18:38:25,556 - gensim.models.word2vec - INFO - PROGRESS: at sentence #790000, processed 11863124 words, keeping 8868 word types
# 2020-03-31 18:38:25,576 - gensim.models.word2vec - INFO - collected 8868 word types from a corpus of 11991485 raw words and 798974 sentences
# 2020-03-31 18:38:25,577 - gensim.models.word2vec - INFO - Loading a fresh vocabulary
# 2020-03-31 18:38:25,593 - gensim.models.word2vec - INFO - effective_min_count=1 retains 8868 unique words (100% of original 8868, drops 0)
# 2020-03-31 18:38:25,593 - gensim.models.word2vec - INFO - effective_min_count=1 leaves 11991485 word corpus (100% of original 11991485, drops 0)
# 2020-03-31 18:38:25,618 - gensim.models.word2vec - INFO - deleting the raw counts dictionary of 8868 items
# 2020-03-31 18:38:25,619 - gensim.models.word2vec - INFO - sample=0.001 downsamples 31 most-common words
# 2020-03-31 18:38:25,620 - gensim.models.word2vec - INFO - downsampling leaves estimated 11279782 word corpus (94.1% of prior 11991485)
# 2020-03-31 18:38:25,645 - gensim.models.base_any2vec - INFO - estimated required memory for 8868 words and 300 dimensions: 25717200 bytes
# 2020-03-31 18:38:25,646 - gensim.models.word2vec - INFO - resetting layer weights
# 2020-03-31 18:38:27,036 - gensim.models.base_any2vec - INFO - training model with 8 workers on 8868 vocabulary and 300 features, using sg=1 hs=0 sample=0.001 negative=5 window=5
# 2020-03-31 18:38:28,067 - gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 3.95% examples, 441165 words/s, in_qsize 15, out_qsize 0
# 2020-03-31 18:38:29,085 - gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 8.65% examples, 479224 words/s, in_qsize 15, out_qsize 0
# 2020-03-31 18:38:30,155 - gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 13.28% examples, 474357 words/s, in_qsize 15, out_qsize 0
# 2020-03-31 18:38:31,156 - gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 17.63% examples, 479886 words/s, in_qsize 13, out_qsize 2
# 2020-03-31 18:38:32,175 - gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 22.00% examples, 479611 words/s, in_qsize 15, out_qsize 0
# 2020-03-31 18:38:33,185 - gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at 26.27% examples, 478709 words/s, in_qsize 15, out_qsize 0
# 2020-03-31 18:38:34,201 - gensim.models.base_any2vec - INFO - EPOCH 1 - PROGRESS: at
- gensim.models.base_any2vec - INFO - EPOCH 49 - PROGRESS: at 88.44% examples, 424334 words/s, in_qsize 15, out_qsize 0
# 2020-03-31 18:58:57,825 - gensim.models.base_any2vec - INFO - EPOCH 49 - PROGRESS: at 92.55% examples, 425614 words/s, in_qsize 15, out_qsize 0
# 2020-03-31 18:58:58,826 - gensim.models.base_any2vec - INFO - EPOCH 49 - PROGRESS: at 96.47% examples, 425880 words/s, in_qsize 14, out_qsize 1
# 2020-03-31 18:58:59,506 - gensim.models.base_any2vec - INFO - worker thread finished; awaiting finish of 7 more threads
# 2020-03-31 18:58:59,524 - gensim.models.base_any2vec - INFO - worker thread finished; awaiting finish of 6 more threads
# 2020-03-31 18:58:59,527 - gensim.models.base_any2vec - INFO - worker thread finished; awaiting finish of 5 more threads
# 2020-03-31 18:58:59,537 - gensim.models.base_any2vec - INFO - worker thread finished; awaiting finish of 4 more threads
# 2020-03-31 18:58:59,548 - gensim.models.base_any2vec - INFO - worker thread finished; awaiting finish of 3 more threads
# 2020-03-31 18:58:59,598 - gensim.models.base_any2vec - INFO - worker thread finished; awaiting finish of 2 more threads
# 2020-03-31 18:58:59,600 - gensim.models.base_any2vec - INFO - worker thread finished; awaiting finish of 1 more threads
# 2020-03-31 18:58:59,609 - gensim.models.base_any2vec - INFO - worker thread finished; awaiting finish of 0 more threads
# 2020-03-31 18:58:59,610 - gensim.models.base_any2vec - INFO - EPOCH - 49 : training on 11991485 raw words (11279155 effective words) took 26.4s, 427191 effective words/s
# 2020-03-31 18:59:00,626 - gensim.models.base_any2vec - INFO - EPOCH 50 - PROGRESS: at 3.20% examples, 364262 words/s, in_qsize 13, out_qsize 2
# 2020-03-31 18:59:01,652 - gensim.models.base_any2vec - INFO - EPOCH 50 - PROGRESS: at 7.41% examples, 411482 words/s, in_qsize 15, out_qsize 0
# 2020-03-31 18:59:02,663 - gensim.models.base_any2vec - INFO - EPOCH 50 - PROGRESS: at 11.74% examples, 429213 words/s, in_qsize 15, out_qsize 0
# 2020-03-31 18:59:03,688 - gensim.models.base_any2vec - INFO - EPOCH 50 - PROGRESS: at 16.00% examples, 438828 words/s, in_qsize 15, out_qsize 0
# 2020-03-31 18:59:04,721 - gensim.models.base_any2vec - INFO - EPOCH 50 - PROGRESS: at 19.95% examples, 439939 words/s, in_qsize 13, out_qsize 2
# 2020-03-31 18:59:05,722 - gensim.models.base_any2vec - INFO - EPOCH 50 - PROGRESS: at 24.44% examples, 446151 words/s, in_qsize 15, out_qsize 0
# 2020-03-31 18:59:06,739 - gensim.models.base_any2vec - INFO - EPOCH 50 - PROGRESS: at 28.38% examples, 448573 words/s, in_qsize 14, out_qsize 1
# 2020-03-31 18:59:07,754 - gensim.models.base_any2vec - INFO - EPOCH 50 - PROGRESS: at 32.38% examples, 448179 words/s, in_qsize 16, out_qsize 2
# 2020-03-31 18:59:08,762 - gensim.models.base_any2vec - INFO - EPOCH 50 - PROGRESS: at 36.47% examples, 450948 words/s, in_qsize 16, out_qsize 1
# 2020-03-31 18:59:09,766 - gensim.models.base_any2vec - INFO - EPOCH 50 - PROGRESS: at 40.75% examples, 453570 words/s, in_qsize 15, out_qsize 0
# 2020-03-31 18:59:10,795 - gensim.models.base_any2vec - INFO - EPOCH 50 - PROGRESS: at 44.82% examples, 455612 words/s, in_qsize 15, out_qsize 0
# 2020-03-31 18:59:11,806 - gensim.models.base_any2vec - INFO - EPOCH 50 - PROGRESS: at 48.67% examples, 455666 words/s, in_qsize 15, out_qsize 0
# 2020-03-31 18:59:12,824 - gensim.models.base_any2vec - INFO - EPOCH 50 - PROGRESS: at 52.89% examples, 456118 words/s, in_qsize 15, out_qsize 0
# 2020-03-31 18:59:13,892 - gensim.models.base_any2vec - INFO - EPOCH 50 - PROGRESS: at 56.95% examples, 455666 words/s, in_qsize 15, out_qsize 0
# 2020-03-31 18:59:14,923 - gensim.models.base_any2vec - INFO - EPOCH 50 - PROGRESS: at 61.59% examples, 456853 words/s, in_qsize 15, out_qsize 0
# 2020-03-31 18:59:15,925 - gensim.models.base_any2vec - INFO - EPOCH 50 - PROGRESS: at 65.59% examples, 457071 words/s, in_qsize 14, out_qsize 1
# 2020-03-31 18:59:16,979 - gensim.models.base_any2vec - INFO - EPOCH 50 - PROGRESS: at 69.94% examples, 455335 words/s, in_qsize 15, out_qsize 0
# 2020-03-31 18:59:17,980 - gensim.models.base_any2vec - INFO - EPOCH 50 - PROGRESS: at 73.12% examples, 449965 words/s, in_qsize 15, out_qsize 0
# 2020-03-31 18:59:19,001 - gensim.models.base_any2vec - INFO - EPOCH 50 - PROGRESS: at 76.44% examples, 445117 words/s, in_qsize 15, out_qsize 0
# 2020-03-31 18:59:20,030 - gensim.models.base_any2vec - INFO - EPOCH 50 - PROGRESS: at 79.59% examples, 441136 words/s, in_qsize 15, out_qsize 0
# 2020-03-31 18:59:21,045 - gensim.models.base_any2vec - INFO - EPOCH 50 - PROGRESS: at 83.03% examples, 438655 words/s, in_qsize 16, out_qsize 0
# 2020-03-31 18:59:22,090 - gensim.models.base_any2vec - INFO - EPOCH 50 - PROGRESS: at 87.33% examples, 439545 words/s, in_qsize 15, out_qsize 0
# 2020-03-31 18:59:23,126 - gensim.models.base_any2vec - INFO - EPOCH 50 - PROGRESS: at 91.51% examples, 440560 words/s, in_qsize 16, out_qsize 1
# 2020-03-31 18:59:24,152 - gensim.models.base_any2vec - INFO - EPOCH 50 - PROGRESS: at 95.65% examples, 441248 words/s, in_qsize 13, out_qsize 2
# 2020-03-31 18:59:24,955 - gensim.models.base_any2vec - INFO - worker thread finished; awaiting finish of 7 more threads
# 2020-03-31 18:59:24,971 - gensim.models.base_any2vec - INFO - worker thread finished; awaiting finish of 6 more threads
# 2020-03-31 18:59:24,973 - gensim.models.base_any2vec - INFO - worker thread finished; awaiting finish of 5 more threads
# 2020-03-31 18:59:24,988 - gensim.models.base_any2vec - INFO - worker thread finished; awaiting finish of 4 more threads
# 2020-03-31 18:59:24,993 - gensim.models.base_any2vec - INFO - worker thread finished; awaiting finish of 3 more threads
# 2020-03-31 18:59:24,995 - gensim.models.base_any2vec - INFO - worker thread finished; awaiting finish of 2 more threads
# 2020-03-31 18:59:25,011 - gensim.models.base_any2vec - INFO - worker thread finished; awaiting finish of 1 more threads
# 2020-03-31 18:59:25,058 - gensim.models.base_any2vec - INFO - worker thread finished; awaiting finish of 0 more threads
# 2020-03-31 18:59:25,058 - gensim.models.base_any2vec - INFO - EPOCH - 50 : training on 11991485 raw words (11279461 effective words) took 25.4s, 443361 effective words/s
# 2020-03-31 18:59:25,059 - gensim.models.base_any2vec - INFO - training on a 599574250 raw words (563992768 effective words) took 1258.0s, 448317 effective words/s

# %%
#model.save('./data/04_features/embeddings.bin')
# Out:
# 2020-03-31 18:59:25,064 - gensim.utils - INFO - saving Word2Vec object under ./data/04_features/embeddings.bin, separately None
# 2020-03-31 18:59:25,065 - gensim.utils - INFO - not storing attribute vectors_norm
# 2020-03-31 18:59:25,066 - gensim.utils - INFO - not storing attribute cum_table
# 2020-03-31 18:59:25,307 - gensim.utils - INFO - saved ./data/04_features/embeddings.bin

# %% [markdown]
# ## Get embeddings

# %%
model = Word2Vec.load('./data/04_features/word2vec_model.bin')
# Out:
# 2020-04-03 11:01:14,552 - gensim.utils - INFO - loading Word2Vec object from ./data/04_features/word2vec_model.bin
# 2020-04-03 11:01:15,005 - gensim.utils - INFO - loading wv recursively from ./data/04_features/word2vec_model.bin.wv.* with mmap=None
# 2020-04-03 11:01:15,006 - gensim.utils - INFO - setting ignored attribute vectors_norm to None
# 2020-04-03 11:01:15,006 - gensim.utils - INFO - loading vocabulary recursively from ./data/04_features/word2vec_model.bin.vocabulary.* with mmap=None
# 2020-04-03 11:01:15,007 - gensim.utils - INFO - loading trainables recursively from ./data/04_features/word2vec_model.bin.trainables.* with mmap=None
# 2020-04-03 11:01:15,008 - gensim.utils - INFO - setting ignored attribute cum_table to None
# 2020-04-03 11:01:15,008 - gensim.utils - INFO - loaded ./data/04_features/word2vec_model.bin

# %%
def get_embeddings(model, vocab):
    # Check embeddings
    print('Vocab length:', len(model.wv.vocab))
    print('Embedding size:', model.vector_size)
    print('Most similar to "war" in embedding space:', model.most_similar('war'))
    war, cold = model['war'].reshape((1, -1)), model['cold'].reshape((1, -1))
    print('Cosine distance between "cold" and "war" in embedding space (gensim metric):', model.similarity('cold', 'war'))
    print('Cosine distance between "cold" and "war" in embedding space (sklearn metric):', cosine_similarity(cold, war))

    words = list(vocab.token2id)
    words = [w for w in words if w in model.wv.vocab]

    embeddings = np.array([model[w] for w in words])
    embeddings_norm = preprocessing.normalize(embeddings)

    dict_embeddings = {w:emb for w,emb in zip(words, embeddings)}
    dict_embeddings_norm = {w:emb for w,emb in zip(words, embeddings_norm)}

    return dict_embeddings, dict_embeddings_norm

# %%
dict_embeddings, dict_embeddings_norm = get_embeddings(model, vocab)
# Out:
# Vocab length: 4895
# Embedding size: 300
# 2020-04-03 11:01:19,985 - gensim.models.keyedvectors - INFO - precomputing L2-norms of word weight vectors
# Most similar to "war" in embedding space: [('world_war', 0.4436487555503845), ('gulf', 0.4100189208984375), ('massacre', 0.4027578830718994), ('serb', 0.36117807030677795), ('britain', 0.34083133935928345), ('bosnian', 0.33297497034072876), ('ottoman', 0.3318420648574829), ('jew', 0.32354503870010376), ('arab', 0.3178195655345917), ('muslim', 0.31602174043655396)]
# Cosine distance between "cold" and "war" in embedding space (gensim metric): 0.12926339
# Cosine distance between "cold" and "war" in embedding space (sklearn metric): [[0.12926337]]
# /home/ridouane/anaconda3/envs/dynamic-topic-modeling/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """
# /home/ridouane/anaconda3/envs/dynamic-topic-modeling/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# /home/ridouane/anaconda3/envs/dynamic-topic-modeling/lib/python3.6/site-packages/ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   import sys
# /home/ridouane/anaconda3/envs/dynamic-topic-modeling/lib/python3.6/site-packages/ipykernel_launcher.py:13: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   del sys.path[0]

# %% [markdown]
# ## Eval / Visualize word embeddings

# %%
words = list(vocab.token2id)
words = [w for w in words if w in w2v.wv.vocab]
embeddings = np.array([model[w] for w in words])
embeddings_norm = preprocessing.normalize(embeddings)

# %%
from sklearn.manifold import TSNE

#X_embedded = TSNE(n_components=2, metric='cosine').fit_transform(embeddings)
X_embedded = TSNE(n_components=2).fit_transform(embeddings_norm)
#Y_embedded = model.predict(embeddings_norm)

# %%
plt.figure(figsize=(20, 20))
plt.scatter(X_embedded[:,0], X_embedded[:,1], s=20)
plt.show()
