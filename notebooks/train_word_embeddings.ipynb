# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics.pairwise import cosine_similarity
from sklearn import preprocessing

from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from gensim.models import Phrases
from gensim.corpora import Dictionary
from gensim.models import Word2Vec

# %%
dataset = catalog.load('raw_dataset')
vocab = catalog.load('dictionary')
# Out:
# 2020-04-10 13:53:45,023 - kedro.io.data_catalog - INFO - Loading data from `raw_dataset` (CSVLocalDataSet)...
# 2020-04-10 13:53:45,943 - kedro.io.data_catalog - INFO - Loading data from `dictionary` (DictionaryDataSet)...
# 2020-04-10 13:53:45,944 - gensim.utils - INFO - loading Dictionary object from data/05_model_input/dictionary.dict
# 2020-04-10 13:53:45,948 - gensim.utils - INFO - loaded data/05_model_input/dictionary.dict

# %% [markdown]
# ## Pre-process docs for word embeddings

# %%
def split_by_sentence(docs):
    tmp = []
    for i, doc in enumerate(docs):
        splitted_doc = doc.split('.\n')
        for sd in splitted_doc:
            sentences = sd.split('. ')
            for s in sentences:
                tmp.append(s)
    return tmp

def lowerize(docs):
    # Convert to lowercase.
    for idx in range(len(docs)):
        docs[idx] = str(docs[idx]).lower()
    return docs

def tokenize(docs):
    # Split into words.
    tokenizer = RegexpTokenizer(r'\w+')
    for idx in range(len(docs)):
        docs[idx] = tokenizer.tokenize(docs[idx])
    return docs

def remove_stop_words(docs):
    stop_words = set(stopwords.words('english'))
    for idx in range(len(docs)):
        docs[idx] = [w for w in docs[idx] if not w in stop_words]
    return docs

def remove_numbers(docs):
    # Remove numbers, but not words that contain numbers.
    docs = [[token for token in doc if not token.isnumeric()] for doc in docs]
    return docs

def remove_word_with_length(docs, length=1):
    # Remove words that are only (length=1) character.
    docs = [[token for token in doc if len(token) > length] for doc in docs]
    return docs

def lemmatize(docs):
    # Lemmatize the documents
    lemmatizer = WordNetLemmatizer()
    docs = [[lemmatizer.lemmatize(token) for token in doc] for doc in docs]
    return docs

def add_bigram(docs, min_bigram_count=20):
    # Add bigrams and trigrams to docs (only ones that appear 20 times or more).
    bigram = Phrases(docs, min_count=min_bigram_count)
    for idx in range(len(docs)):
        for token in bigram[docs[idx]]:
            if '_' in token:
                # Token is a bigram, add to document.
                docs[idx].append(token)
    return docs

def remove_vocab(docs, vocab):
    docs = np.array([[w for w in doc if w in vocab] for doc in docs])
    return docs

# %%
min_bigram_count = 20
length = 1
no_below = 100
no_above = 0.70

docs = dataset['text'].values

print('\nSplitting by sentence...')
docs = split_by_sentence(docs)

print('\nLowerizing...')
docs = lowerize(docs)

print('\nTokenizing...')
docs = tokenize(docs)

#print('\nAdding bigrams...')
#docs = add_bigram(docs, min_bigram_count=min_bigram_count)
    
print('\nRemoving stop words...')
docs = remove_stop_words(docs)

print('\nRemoving unique numbers (not words that contain numbers)...')
docs = remove_numbers(docs)

print('\nRemoving words that contain only one character...')
docs = remove_word_with_length(docs, length=length)

print('\nLemmatizing...')
docs = lemmatize(docs)

vocab = Dictionary(docs)
vocab.filter_extremes(no_below=no_below, no_above=no_above)

docs = remove_vocab(docs, list(vocab.token2id))

print('Number of sentences:', len(docs))
print('Number of unique words:', len(vocab))
# Out:
# Splitting by sentence...
#
# Lowerizing...
#
# Tokenizing...
#
# Removing stop words...
#
# Removing unique numbers (not words that contain numbers)...
#
# Removing words that contain only one character...
#
# Lemmatizing...
# 2020-04-10 13:54:50,021 - gensim.corpora.dictionary - INFO - adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-10 13:54:50,207 - gensim.corpora.dictionary - INFO - adding document #10000 to Dictionary(9529 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:50,403 - gensim.corpora.dictionary - INFO - adding document #20000 to Dictionary(12395 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:50,601 - gensim.corpora.dictionary - INFO - adding document #30000 to Dictionary(15222 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:50,775 - gensim.corpora.dictionary - INFO - adding document #40000 to Dictionary(17050 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:50,960 - gensim.corpora.dictionary - INFO - adding document #50000 to Dictionary(18217 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:51,176 - gensim.corpora.dictionary - INFO - adding document #60000 to Dictionary(19315 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:51,386 - gensim.corpora.dictionary - INFO - adding document #70000 to Dictionary(20425 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:51,570 - gensim.corpora.dictionary - INFO - adding document #80000 to Dictionary(21319 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:51,776 - gensim.corpora.dictionary - INFO - adding document #90000 to Dictionary(22182 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:51,978 - gensim.corpora.dictionary - INFO - adding document #100000 to Dictionary(22850 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:52,188 - gensim.corpora.dictionary - INFO - adding document #110000 to Dictionary(23656 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:52,413 - gensim.corpora.dictionary - INFO - adding document #120000 to Dictionary(24431 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:52,603 - gensim.corpora.dictionary - INFO - adding document #130000 to Dictionary(24929 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:52,804 - gensim.corpora.dictionary - INFO - adding document #140000 to Dictionary(25763 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:53,018 - gensim.corpora.dictionary - INFO - adding document #150000 to Dictionary(26360 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:53,236 - gensim.corpora.dictionary - INFO - adding document #160000 to Dictionary(26847 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:53,437 - gensim.corpora.dictionary - INFO - adding document #170000 to Dictionary(27322 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:53,617 - gensim.corpora.dictionary - INFO - adding document #180000 to Dictionary(27862 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:53,815 - gensim.corpora.dictionary - INFO - adding document #190000 to Dictionary(28212 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:54,027 - gensim.corpora.dictionary - INFO - adding document #200000 to Dictionary(28631 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:54,234 - gensim.corpora.dictionary - INFO - adding document #210000 to Dictionary(29189 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:54,437 - gensim.corpora.dictionary - INFO - adding document #220000 to Dictionary(29622 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:54,665 - gensim.corpora.dictionary - INFO - adding document #230000 to Dictionary(30074 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:54,865 - gensim.corpora.dictionary - INFO - adding document #240000 to Dictionary(30416 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:55,050 - gensim.corpora.dictionary - INFO - adding document #250000 to Dictionary(30723 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:55,261 - gensim.corpora.dictionary - INFO - adding document #260000 to Dictionary(31083 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:55,489 - gensim.corpora.dictionary - INFO - adding document #270000 to Dictionary(31420 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:55,730 - gensim.corpora.dictionary - INFO - adding document #280000 to Dictionary(31689 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:55,929 - gensim.corpora.dictionary - INFO - adding document #290000 to Dictionary(32047 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:56,115 - gensim.corpora.dictionary - INFO - adding document #300000 to Dictionary(32389 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:56,295 - gensim.corpora.dictionary - INFO - adding document #310000 to Dictionary(32726 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:56,493 - gensim.corpora.dictionary - INFO - adding document #320000 to Dictionary(33418 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:56,740 - gensim.corpora.dictionary - INFO - adding document #330000 to Dictionary(33890 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:56,954 - gensim.corpora.dictionary - INFO - adding document #340000 to Dictionary(34297 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:57,165 - gensim.corpora.dictionary - INFO - adding document #350000 to Dictionary(34642 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:57,399 - gensim.corpora.dictionary - INFO - adding document #360000 to Dictionary(34910 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:57,630 - gensim.corpora.dictionary - INFO - adding document #370000 to Dictionary(35175 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:57,866 - gensim.corpora.dictionary - INFO - adding document #380000 to Dictionary(35440 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:58,093 - gensim.corpora.dictionary - INFO - adding document #390000 to Dictionary(35685 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:58,315 - gensim.corpora.dictionary - INFO - adding document #400000 to Dictionary(35989 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:58,525 - gensim.corpora.dictionary - INFO - adding document #410000 to Dictionary(36284 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:58,718 - gensim.corpora.dictionary - INFO - adding document #420000 to Dictionary(36535 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:58,913 - gensim.corpora.dictionary - INFO - adding document #430000 to Dictionary(36785 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:59,119 - gensim.corpora.dictionary - INFO - adding document #440000 to Dictionary(37465 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:59,357 - gensim.corpora.dictionary - INFO - adding document #450000 to Dictionary(38154 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:59,575 - gensim.corpora.dictionary - INFO - adding document #460000 to Dictionary(38527 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:59,778 - gensim.corpora.dictionary - INFO - adding document #470000 to Dictionary(38853 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:54:59,959 - gensim.corpora.dictionary - INFO - adding document #480000 to Dictionary(39070 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:00,133 - gensim.corpora.dictionary - INFO - adding document #490000 to Dictionary(39276 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:00,307 - gensim.corpora.dictionary - INFO - adding document #500000 to Dictionary(39546 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:00,498 - gensim.corpora.dictionary - INFO - adding document #510000 to Dictionary(39746 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:00,690 - gensim.corpora.dictionary - INFO - adding document #520000 to Dictionary(39941 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:00,862 - gensim.corpora.dictionary - INFO - adding document #530000 to Dictionary(40227 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:01,036 - gensim.corpora.dictionary - INFO - adding document #540000 to Dictionary(40514 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:01,211 - gensim.corpora.dictionary - INFO - adding document #550000 to Dictionary(40722 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:01,397 - gensim.corpora.dictionary - INFO - adding document #560000 to Dictionary(41011 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:01,619 - gensim.corpora.dictionary - INFO - adding document #570000 to Dictionary(41386 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:01,833 - gensim.corpora.dictionary - INFO - adding document #580000 to Dictionary(41650 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:02,039 - gensim.corpora.dictionary - INFO - adding document #590000 to Dictionary(41912 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:02,262 - gensim.corpora.dictionary - INFO - adding document #600000 to Dictionary(42114 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:02,453 - gensim.corpora.dictionary - INFO - adding document #610000 to Dictionary(42322 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:02,653 - gensim.corpora.dictionary - INFO - adding document #620000 to Dictionary(42526 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:02,850 - gensim.corpora.dictionary - INFO - adding document #630000 to Dictionary(42782 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:03,054 - gensim.corpora.dictionary - INFO - adding document #640000 to Dictionary(43214 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:03,250 - gensim.corpora.dictionary - INFO - adding document #650000 to Dictionary(43569 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:03,431 - gensim.corpora.dictionary - INFO - adding document #660000 to Dictionary(43749 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:03,614 - gensim.corpora.dictionary - INFO - adding document #670000 to Dictionary(43986 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:03,821 - gensim.corpora.dictionary - INFO - adding document #680000 to Dictionary(44153 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:04,038 - gensim.corpora.dictionary - INFO - adding document #690000 to Dictionary(44417 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:04,227 - gensim.corpora.dictionary - INFO - adding document #700000 to Dictionary(44674 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:04,432 - gensim.corpora.dictionary - INFO - adding document #710000 to Dictionary(44971 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:04,651 - gensim.corpora.dictionary - INFO - adding document #720000 to Dictionary(45314 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:04,861 - gensim.corpora.dictionary - INFO - adding document #730000 to Dictionary(45477 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:05,068 - gensim.corpora.dictionary - INFO - adding document #740000 to Dictionary(45664 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:05,282 - gensim.corpora.dictionary - INFO - adding document #750000 to Dictionary(45976 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:05,481 - gensim.corpora.dictionary - INFO - adding document #760000 to Dictionary(46157 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:05,667 - gensim.corpora.dictionary - INFO - adding document #770000 to Dictionary(46310 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:05,856 - gensim.corpora.dictionary - INFO - adding document #780000 to Dictionary(46498 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:06,044 - gensim.corpora.dictionary - INFO - adding document #790000 to Dictionary(46641 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# 2020-04-10 13:55:06,220 - gensim.corpora.dictionary - INFO - built Dictionary(46754 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...) from 798974 documents (total 11265309 corpus positions)
# 2020-04-10 13:55:06,271 - gensim.corpora.dictionary - INFO - discarding 39819 tokens: [('assiduous', 18), ('regeneration', 50), ('thawing', 19), ('precariousness', 35), ('simmer', 8), ('intellect', 41), ('resourceful', 19), ('horizontally', 14), ('vertically', 20), ('stifling', 80)]...
# 2020-04-10 13:55:06,272 - gensim.corpora.dictionary - INFO - keeping 6935 tokens which were in no less than 100 and no more than 559281 (=70.0%) documents
# 2020-04-10 13:55:06,289 - gensim.corpora.dictionary - INFO - resulting dictionary: Dictionary(6935 unique tokens: ['ambassador', 'assembly', 'congratulation', 'delegation', 'election']...)
# Number of sentences: 798974
# Number of unique words: 6935

# %% [markdown]
# ## Train word embeddings (gensim word2vec)

# %%
class MyDocuments(object):
    def __init__(self, docs):
        self.docs = docs
 
    def __iter__(self):
        for line in self.docs:
            yield line

# %%
sentences = MyDocuments(docs)

# %%
size = 300
window = 5
min_count = 1
workers = 8
sg = 1
iter = 50

model = Word2Vec(sentences, size=size, window=window, min_count=min_count, workers=workers, sg=sg, iter=iter)
# Out:
# 2020-04-10 13:59:34,018 - gensim.models.word2vec - INFO - collecting all words and their counts
# 2020-04-10 13:59:34,019 - gensim.models.word2vec - INFO - PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-04-10 13:59:34,042 - gensim.models.word2vec - INFO - PROGRESS: at sentence #10000, processed 137391 words, keeping 6041 word types
# 2020-04-10 13:59:34,068 - gensim.models.word2vec - INFO - PROGRESS: at sentence #20000, processed 272256 words, keeping 6527 word types
# 2020-04-10 13:59:34,097 - gensim.models.word2vec - INFO - PROGRESS: at sentence #30000, processed 416218 words, keeping 6719 word types
# 2020-04-10 13:59:34,125 - gensim.models.word2vec - INFO - PROGRESS: at sentence #40000, processed 540054 words, keeping 6814 word types
# 2020-04-10 13:59:34,154 - gensim.models.word2vec - INFO - PROGRESS: at sentence #50000, processed 674162 words, keeping 6846 word types
# 2020-04-10 13:59:34,182 - gensim.models.word2vec - INFO - PROGRESS: at sentence #60000, processed 815755 words, keeping 6857 word types
# 2020-04-10 13:59:34,208 - gensim.models.word2vec - INFO - PROGRESS: at sentence #70000, processed 951144 words, keeping 6872 word types
# 2020-04-10 13:59:34,232 - gensim.models.word2vec - INFO - PROGRESS: at sentence #80000, processed 1075302 words, keeping 6879 word types
# 2020-04-10 13:59:34,260 - gensim.models.word2vec - INFO - PROGRESS: at sentence #90000, processed 1207075 words, keeping 6884 word types
# 2020-04-10 13:59:34,288 - gensim.models.word2vec - INFO - PROGRESS: at sentence #100000, processed 1339313 words, keeping 6886 word types
# 2020-04-10 13:59:34,318 - gensim.models.word2vec - INFO - PROGRESS: at sentence #110000, processed 1480621 words, keeping 6888 word types
# 2020-04-10 13:59:34,342 - gensim.models.word2vec - INFO - PROGRESS: at sentence #120000, processed 1616146 words, keeping 6893 word types
# 2020-04-10 13:59:34,367 - gensim.models.word2vec - INFO - PROGRESS: at sentence #130000, processed 1743502 words, keeping 6898 word types
# 2020-04-10 13:59:34,395 - gensim.models.word2vec - INFO - PROGRESS: at sentence #140000, processed 1887149 words, keeping 6901 word types
# 2020-04-10 13:59:34,425 - gensim.models.word2vec - INFO - PROGRESS: at sentence #150000, processed 2032420 words, keeping 6904 word types
# 2020-04-10 13:59:34,452 - gensim.models.word2vec - INFO - PROGRESS: at sentence #160000, processed 2168620 words, keeping 6905 word types
# 2020-04-10 13:59:34,477 - gensim.models.word2vec - INFO - PROGRESS: at sentence #170000, processed 2296772 words, keeping 6907 word types
# 2020-04-10 13:59:34,499 - gensim.models.word2vec - INFO - PROGRESS: at sentence #180000, processed 2421381 words, keeping 6908 word types
# 2020-04-10 13:59:34,522 - gensim.models.word2vec - INFO - PROGRESS: at sentence #190000, processed 2550479 words, keeping 6910 word types
# 2020-04-10 13:59:34,545 - gensim.models.word2vec - INFO - PROGRESS: at sentence #200000, processed 2683412 words, keeping 6911 word types
# 2020-04-10 13:59:34,580 - gensim.models.word2vec - INFO - PROGRESS: at sentence #210000, processed 2828912 words, keeping 6913 word types
# 2020-04-10 13:59:34,611 - gensim.models.word2vec - INFO - PROGRESS: at sentence #220000, processed 2974708 words, keeping 6913 word types
# 2020-04-10 13:59:34,635 - gensim.models.word2vec - INFO - PROGRESS: at sentence #230000, processed 3117934 words, keeping 6914 word types
# 2020-04-10 13:59:34,666 - gensim.models.word2vec - INFO - PROGRESS: at sentence #240000, processed 3257689 words, keeping 6917 word types
# 2020-04-10 13:59:34,690 - gensim.models.word2vec - INFO - PROGRESS: at sentence #250000, processed 3383881 words, keeping 6917 word types
# 2020-04-10 13:59:34,720 - gensim.models.word2vec - INFO - PROGRESS: at sentence #260000, processed 3520637 words, keeping 6917 word types
# 2020-04-10 13:59:34,748 - gensim.models.word2vec - INFO - PROGRESS: at sentence #270000, processed 3663077 words, keeping 6917 word types
# 2020-04-10 13:59:34,774 - gensim.models.word2vec - INFO - PROGRESS: at sentence #280000, processed 3805942 words, keeping 6917 word types
# 2020-04-10 13:59:34,802 - gensim.models.word2vec - INFO - PROGRESS: at sentence #290000, processed 3943388 words, keeping 6917 word types
# 2020-04-10 13:59:34,827 - gensim.models.word2vec - INFO - PROGRESS: at sentence #300000, processed 4072473 words, keeping 6918 word types
# 2020-04-10 13:59:34,848 - gensim.models.word2vec - INFO - PROGRESS: at sentence #310000, processed 4197461 words, keeping 6919 word types
# 2020-04-10 13:59:34,874 - gensim.models.word2vec - INFO - PROGRESS: at sentence #320000, processed 4341584 words, keeping 6920 word types
# 2020-04-10 13:59:34,900 - gensim.models.word2vec - INFO - PROGRESS: at sentence #330000, processed 4489798 words, keeping 6921 word types
# 2020-04-10 13:59:34,927 - gensim.models.word2vec - INFO - PROGRESS: at sentence #340000, processed 4638116 words, keeping 6921 word types
# 2020-04-10 13:59:34,952 - gensim.models.word2vec - INFO - PROGRESS: at sentence #350000, processed 4782378 words, keeping 6922 word types
# 2020-04-10 13:59:34,975 - gensim.models.word2vec - INFO - PROGRESS: at sentence #360000, processed 4920178 words, keeping 6922 word types
# 2020-04-10 13:59:35,000 - gensim.models.word2vec - INFO - PROGRESS: at sentence #370000, processed 5070283 words, keeping 6922 word types
# 2020-04-10 13:59:35,027 - gensim.models.word2vec - INFO - PROGRESS: at sentence #380000, processed 5221841 words, keeping 6922 word types
# 2020-04-10 13:59:35,052 - gensim.models.word2vec - INFO - PROGRESS: at sentence #390000, processed 5355154 words, keeping 6924 word types
# 2020-04-10 13:59:35,078 - gensim.models.word2vec - INFO - PROGRESS: at sentence #400000, processed 5489056 words, keeping 6924 word types
# 2020-04-10 13:59:35,103 - gensim.models.word2vec - INFO - PROGRESS: at sentence #410000, processed 5615853 words, keeping 6925 word types
# 2020-04-10 13:59:35,132 - gensim.models.word2vec - INFO - PROGRESS: at sentence #420000, processed 5751980 words, keeping 6925 word types
# 2020-04-10 13:59:35,159 - gensim.models.word2vec - INFO - PROGRESS: at sentence #430000, processed 5895218 words, keeping 6925 word types
# 2020-04-10 13:59:35,186 - gensim.models.word2vec - INFO - PROGRESS: at sentence #440000, processed 6037637 words, keeping 6926 word types
# 2020-04-10 13:59:35,211 - gensim.models.word2vec - INFO - PROGRESS: at sentence #450000, processed 6179032 words, keeping 6926 word types
# 2020-04-10 13:59:35,236 - gensim.models.word2vec - INFO - PROGRESS: at sentence #460000, processed 6316927 words, keeping 6926 word types
# 2020-04-10 13:59:35,258 - gensim.models.word2vec - INFO - PROGRESS: at sentence #470000, processed 6441753 words, keeping 6926 word types
# 2020-04-10 13:59:35,281 - gensim.models.word2vec - INFO - PROGRESS: at sentence #480000, processed 6569397 words, keeping 6927 word types
# 2020-04-10 13:59:35,304 - gensim.models.word2vec - INFO - PROGRESS: at sentence #490000, processed 6693267 words, keeping 6927 word types
# 2020-04-10 13:59:35,326 - gensim.models.word2vec - INFO - PROGRESS: at sentence #500000, processed 6821899 words, keeping 6927 word types
# 2020-04-10 13:59:35,351 - gensim.models.word2vec - INFO - PROGRESS: at sentence #510000, processed 6962303 words, keeping 6928 word types
# 2020-04-10 13:59:35,376 - gensim.models.word2vec - INFO - PROGRESS: at sentence #520000, processed 7107583 words, keeping 6928 word types
# 2020-04-10 13:59:35,398 - gensim.models.word2vec - INFO - PROGRESS: at sentence #530000, processed 7232686 words, keeping 6930 word types
# 2020-04-10 13:59:35,421 - gensim.models.word2vec - INFO - PROGRESS: at sentence #540000, processed 7357713 words, keeping 6930 word types
# 2020-04-10 13:59:35,446 - gensim.models.word2vec - INFO - PROGRESS: at sentence #550000, processed 7480225 words, keeping 6930 word types
# 2020-04-10 13:59:35,469 - gensim.models.word2vec - INFO - PROGRESS: at sentence #560000, processed 7616567 words, keeping 6930 word types
# 2020-04-10 13:59:35,493 - gensim.models.word2vec - INFO - PROGRESS: at sentence #570000, processed 7760896 words, keeping 6930 word types
# 2020-04-10 13:59:35,518 - gensim.models.word2vec - INFO - PROGRESS: at sentence #580000, processed 7892026 words, keeping 6930 word types
# 2020-04-10 13:59:35,538 - gensim.models.word2vec - INFO - PROGRESS: at sentence #590000, processed 8014610 words, keeping 6934 word types
# 2020-04-10 13:59:35,564 - gensim.models.word2vec - INFO - PROGRESS: at sentence #600000, processed 8150694 words, keeping 6934 word types
# 2020-04-10 13:59:35,588 - gensim.models.word2vec - INFO - PROGRESS: at sentence #610000, processed 8284559 words, keeping 6934 word types
# 2020-04-10 13:59:35,612 - gensim.models.word2vec - INFO - PROGRESS: at sentence #620000, processed 8429663 words, keeping 6934 word types
# 2020-04-10 13:59:35,636 - gensim.models.word2vec - INFO - PROGRESS: at sentence #630000, processed 8573121 words, keeping 6934 word types
# 2020-04-10 13:59:35,659 - gensim.models.word2vec - INFO - PROGRESS: at sentence #640000, processed 8720660 words, keeping 6934 word types
# 2020-04-10 13:59:35,684 - gensim.models.word2vec - INFO - PROGRESS: at sentence #650000, processed 8858603 words, keeping 6934 word types
# 2020-04-10 13:59:35,706 - gensim.models.word2vec - INFO - PROGRESS: at sentence #660000, processed 8991169 words, keeping 6934 word types
# 2020-04-10 13:59:35,727 - gensim.models.word2vec - INFO - PROGRESS: at sentence #670000, processed 9125592 words, keeping 6934 word types
# 2020-04-10 13:59:35,751 - gensim.models.word2vec - INFO - PROGRESS: at sentence #680000, processed 9259631 words, keeping 6934 word types
# 2020-04-10 13:59:35,775 - gensim.models.word2vec - INFO - PROGRESS: at sentence #690000, processed 9394193 words, keeping 6934 word types
# 2020-04-10 13:59:35,798 - gensim.models.word2vec - INFO - PROGRESS: at sentence #700000, processed 9527472 words, keeping 6934 word types
# 2020-04-10 13:59:35,822 - gensim.models.word2vec - INFO - PROGRESS: at sentence #710000, processed 9671901 words, keeping 6934 word types
# 2020-04-10 13:59:35,844 - gensim.models.word2vec - INFO - PROGRESS: at sentence #720000, processed 9814097 words, keeping 6934 word types
# 2020-04-10 13:59:35,867 - gensim.models.word2vec - INFO - PROGRESS: at sentence #730000, processed 9944154 words, keeping 6934 word types
# 2020-04-10 13:59:35,891 - gensim.models.word2vec - INFO - PROGRESS: at sentence #740000, processed 10086230 words, keeping 6934 word types
# 2020-04-10 13:59:35,915 - gensim.models.word2vec - INFO - PROGRESS: at sentence #750000, processed 10229793 words, keeping 6934 word types
# 2020-04-10 13:59:35,937 - gensim.models.word2vec - INFO - PROGRESS: at sentence #760000, processed 10363375 words, keeping 6935 word types
# 2020-04-10 13:59:35,959 - gensim.models.word2vec - INFO - PROGRESS: at sentence #770000, processed 10485356 words, keeping 6935 word types
# 2020-04-10 13:59:35,980 - gensim.models.word2vec - INFO - PROGRESS: at sentence #780000, processed 10607466 words, keeping 6935 word types
# 2020-04-10 13:59:36,003 - gensim.models.word2vec - INFO - PROGRESS: at sentence #790000, processed 10733609 words, keeping 6935 word types
# 2020-04-10 13:59:36,022 - gensim.models.word2vec - INFO - collected 6935 word types from a corpus of 10849021 raw words and 798974 sentences
# 2020-04-10 13:59:36,023 - gensim.models.word2vec - INFO - Loading a fresh vocabulary
# 2020-04-10 13:59:36,039 - gensim.models.word2vec - INFO - effective_min_count=1 retains 6935 unique words (100% of original 6935, drops 0)
# 2020-04-10 14:18:09,473 - gensim.utils - INFO - not storing attribute vectors_norm
# 2020-04-10 14:18:09,608 - gensim.utils - INFO - not storing attribute cum_table
# 2020-04-10 14:18:10,673 - gensim.utils - INFO - saved ./data/04_features/word2vec_model.bin

# %% [markdown]
# ## Get embeddings

# %%
def get_embeddings(model, vocab):
    # Check embeddings
    print('Vocab length:', len(model.wv.vocab))
    print('Embedding size:', model.vector_size)
    print('Most similar to "war" in embedding space:', model.most_similar('war'))
    war, cold = model['war'].reshape((1, -1)), model['cold'].reshape((1, -1))
    print('Cosine distance between "cold" and "war" in embedding space (gensim metric):', model.similarity('cold', 'war'))
    print('Cosine distance between "cold" and "war" in embedding space (sklearn metric):', cosine_similarity(cold, war))

    words = list(vocab.token2id)
    words = [w for w in words if w in model.wv.vocab]

    embeddings = np.array([model[w] for w in words])
    embeddings_norm = preprocessing.normalize(embeddings)

    dict_embeddings = {w:emb for w,emb in zip(words, embeddings)}
    dict_embeddings_norm = {w:emb for w,emb in zip(words, embeddings_norm)}

    return dict_embeddings, dict_embeddings_norm

# %%
dict_embeddings, dict_embeddings_norm = get_embeddings(model, vocab)
# Out:
# Vocab length: 4895
# Embedding size: 300
# 2020-04-10 12:37:14,398 - gensim.models.keyedvectors - INFO - precomputing L2-norms of word weight vectors
# Most similar to "war" in embedding space: [('world_war', 0.4436487555503845), ('gulf', 0.4100189208984375), ('massacre', 0.4027578830718994), ('serb', 0.36117807030677795), ('britain', 0.34083133935928345), ('bosnian', 0.33297497034072876), ('ottoman', 0.3318420648574829), ('jew', 0.32354503870010376), ('arab', 0.3178195655345917), ('muslim', 0.31602174043655396)]
# Cosine distance between "cold" and "war" in embedding space (gensim metric): 0.12926339
# Cosine distance between "cold" and "war" in embedding space (sklearn metric): [[0.12926337]]
# /home/ridouane/anaconda3/envs/dynamic-topic-modeling/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """
# /home/ridouane/anaconda3/envs/dynamic-topic-modeling/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# /home/ridouane/anaconda3/envs/dynamic-topic-modeling/lib/python3.6/site-packages/ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   import sys
# /home/ridouane/anaconda3/envs/dynamic-topic-modeling/lib/python3.6/site-packages/ipykernel_launcher.py:13: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   del sys.path[0]

# %%
import pickle
with open('./data/04_features/dict_embeddings.pkl', 'wb') as handle:
    pickle.dump(dict_embeddings, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('./data/04_features/dict_embeddings_norm.pkl', 'wb') as handle:
    pickle.dump(dict_embeddings_norm, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Eval / Visualize word embeddings

# %%
words = list(vocab.token2id)
words = [w for w in words if w in w2v.wv.vocab]
embeddings = np.array([model[w] for w in words])
embeddings_norm = preprocessing.normalize(embeddings)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c2bfd3faf659> in <module>
# ----> 1 words = list(vocab.token2id)
#       2 words = [w for w in words if w in w2v.wv.vocab]
#       3 embeddings = np.array([model[w] for w in words])
#       4 embeddings_norm = preprocessing.normalize(embeddings)
#
# NameError: name 'vocab' is not defined

# %%
from sklearn.manifold import TSNE

#X_embedded = TSNE(n_components=2, metric='cosine').fit_transform(embeddings)
X_embedded = TSNE(n_components=2).fit_transform(embeddings_norm)
#Y_embedded = model.predict(embeddings_norm)

# %%
plt.figure(figsize=(20, 20))
plt.scatter(X_embedded[:,0], X_embedded[:,1], s=20)
plt.show()
